# %%
import pandas as pd
from konlpy.tag import Kkma
from konlpy.utils import pprint

# %%
register_df = pd.read_csv("./register_info.csv")
print(f"register df shape : {register_df.shape}")

register_df.head()
# Out:
# register df shape : (28578, 7)
#    Unnamed: 0  register_no  product_search_no     report_num  \
# 0           0            1   2020021000186067  2020001605212
# 1           1            2   2020021000187045  2009001702350
# 2           2            3   2020021000186981  2019000939443
# 3           3            4   2020021000186979  2019000939442
# 4           4            5   2020021000186978  2019000939441
#
#           product_name   company_name  register_date
# 0  젬무브 생생 이너핏 신프로바이오틱스  주식회사 코리아헬스바이오       20200512
# 1                더블슬림핏     (주)빅솔 반월공장       20200512
# 2         맛있는 슬림카페 라떼맛      (주) 미누스토리       20200512
# 3      맛있는 슬림카페 바닐라라떼맛      (주) 미누스토리       20200512
# 4  믿을신 신바이오틱스 생유산균 패밀리      (주) 미누스토리       20200512

# %%
product_info = pd.read_csv("./product_info.csv", engine="python")

print(f"product_info shape  : {product_info.shape}")
product_info.head()
# Out:
# product_info shape  : (69875, 15)
#   Unnamed: 0 product_info_id   company_name          product_name  \
# 0          0           11413      (주)세종바이오팜         파워액티브비타민C1000
# 1          1           11414  주식회사 코리아헬스바이오   젬무브 생생 이너핏 신프로바이오틱스
# 2          2           11415       주식회사한미양행           비타민D 2000IU
# 3          3           11416         (주)케비젠  다니스코 5종혼합유산균 300B GN
# 4          4           11417       (주)알피바이오         커스텀바이오 엽산400+
#
#         report_num register_date     expiry_date  \
# 0    2019000910535    2020-03-16   제조일로부터 36개월까지
# 1    2020001605212    2020-05-12  제조일로부터 18개월 까지
# 2  200400150831182    2019-08-23            24개월
# 3    2015001001865    2020-01-14            24개월
# 4   20040017006800    2019-11-13     제조일로부터 24개월
#
#                                           properties  \
# 0                      이미·이취가 없으며, 고유의 향미가 있는 미색의 정제
# 1         이미, 이취가 없고 고유의 향미가 있으며 노란색 입자를 포함한 미백색의 분말
# 2  이미, 이취가 없고 고유의 향미가 지닌 흐린 노란연두색의 내용물을 함유한 투명 연질캡슐.
# 3                   이미, 이취가 없고 고유의 향미가 있는 미백색~미황색 분말
# 4             이미, 이취가 없고 고유의 향미가 있는 연한 노란색의 장방형 제피정제
#
#                         daily_dose  \
# 0  1일 1회, 1회 1정을 충분한 물과 함께 섭취하십시오.
# 1  1일 1회, 1회 1포를 충분한 물과 함께 섭취하십시오.
# 2    1일 1회, 1회 1캡슐을 충분한 물과 함께 섭취.
# 3                    건강기능식품 원료로 사용
# 4  1일 1회, 1회 1정을 충분한 물과 함께 섭취하십시오.
#
#                                         package_type  \
# 0       병포장( 용기 - PET, 캡 - PP) / PTP포장(PVC, AL-Foil)
# 1                                          폴리에틸렌(PE)
# 2  폴리에틸렌(PE), 폴리에틸렌테레프탈레이트(PET), 고밀도폴리에틸렌(HDPE), ...
# 3                                          폴리에틸렌(PE)
# 4  PET(폴리에틸렌테레프탈레이트), PE(알루미늄박폴리에틸렌), HDPE(고밀도폴리에...
#
#                                      storage_caution  \
# 0  1) 습기가 적고, 직사광선을 받지 않는 서늘한 곳에 보관하십시오.2) 본 제품은 ...
# 1                              직사광선 및 고온다습한 곳을 피해 보관
# 2                     고온다습한 곳이나 직사광선을 피하여 서늘한 곳에 보관.
# 3                                                 냉장
# 4  고온다습한 곳과 직사광선을 피해 습기가 적고 건조한 곳에 보관하십시오. 어린이의 손...
#
#                                         warning_info  \
# 0                                                NaN
# 1  질환이 있거나 의약품 복용 시 전문가와 상담할 것알레르기 체질 등은 개인에 따라 과...
# 2                  알레르기 체질이신 경우 성분을 확인한 후 섭취하시기 바랍니다
# 3  - 질환이 있거나 의약품 복용 시 전문가와 상담할 것- 알레르기 체질 등은 개인에 ...
# 4  유통기한을 확인하시기 바라며, 섭취량 및 섭취방법을 준수하시기 바랍니다.특이체질이거...
#
#                                     function_content  \
# 0  ①결합조직 형성과 기능유지에 필요②철의 흡수에 필요③유해산소로부터 세포를 보호하는데 필요
# 1  ①정상적인 면역기능에 필요②정상적인 세포분열에 필요① 유익균 증식 및 유해균 억제·...
# 2  [비타민D] 칼슘과 인이 흡수되고 이용되는데 필요, 뼈의 형성과 유지에 필요, 골다...
# 3  ①유산균 증식 및 유해균 억제에 도움을 줄 수 있음 ②배변활동 원활에 도움을 줄 수...
# 4  [엽산] ①세포와 혈액생성에 필요②태아 신경관의 정상 발달에 필요③혈액의 호모시스테...
#
#                                        standard_info  \
# 0  1. 성상: 이미·이취가 없으며, 고유의 향미가 있는 미색의 정제2. 비타민C: 표...
# 1  (1) 성상 : 이미, 이취가 없고 고유의 향미가 있으면 노란색 입자를 포함한 미백...
# 2  (1) 성상 : 이미, 이취가 없고 고유의 향미가 지닌 흐린 노란연두색의 내용물을 ...
# 3  1. 성상: 이미, 이취가 없고 고유의 향미가 있는 미백색~미황색 분말2. 프로바이...
# 4  1) 성상 : 이미, 이취가 없고 고유의 향미가 있는 연한 노란색의 장방형 제피정제...
#
#                                       materials_info
# 0  비타민 C|비타민 C|스테아린산마그네슘|카르복시메틸셀룰로오스|이산화규소|히드록시프로...
# 1  프락토올리고당|프로바이오틱스|아연|산화아연|프로바이오틱스|프로바이오틱스|프락토올리고...
# 2  비타민D|비타민E|D-알파-토코페롤|비타민D3혼합제제|D-소비톨액|에틸바닐린|글리세...
# 3  프로바이오틱스|Bifidobacterium breve|Bifidobacterium ...
# 4  비타민 B12|엽산|레몬추출분말|건조효모|베리혼합분말|목화씨앗|말토덱스트린혼합제제|...

# %%
product_info.describe()
# Out:
#        Unnamed: 0                                    product_info_id  \
# count       63357                                              42879
# unique      43896                                              39619
# top                특정질환, 특이체질, 알레르기체질, 임산부의 경우에는 간혹 개인에 따라 과민반응이 ...
# freq         1090                                                171
#
#        company_name product_name   report_num register_date  expiry_date  \
# count         36424        30090        29149         28575        28573
# unique         6940        27492        29120          3371          353
# top      코스맥스바이오(주)        홍삼농축액  홍삼제품|홍삼농축액|    2019-07-05  제조일로부터 24개월
# freq           1823           41           10            45         7257
#
#                            properties     daily_dose package_type  \
# count                           28517          28270        28575
# unique                          15337          11236         7791
# top     이미, 이취가 없고 고유의 향미가 있는 미황색의 분말  건강기능식품 원료로 사용    폴리에틸렌(PE)
# freq                              339            837         2057
#
#                        storage_caution                    warning_info  \
# count                            28105                           24850
# unique                            4534                           10575
# top     고온다습한 곳이나 직사광선을 피하여 서늘한 곳에 보관.  의약품(당뇨치료제, 혈액항응고제) 복용 시 섭취에 주의
# freq                               844                            1481
#
#                                          function_content  \
# count                                               24405
# unique                                              10200
# top     ①유산균 증식 및 유해균 억제에 도움을 줄 수 있음 ②배변활동 원활에 도움을 줄 수...
# freq                                                 1250
#
#                                             standard_info materials_info
# count                                               19919          19300
# unique                                              18642          17350
# top     ① 성상 : 이미, 이취가 없고 고유의 향미가 있는 유백색의 분말② 대장균군 : 음...      홍삼|홍삼농축액|
# freq                                                   23            311

# %%
product_info.dtypes
# Out:
# Unnamed: 0          object
# product_info_id     object
# company_name        object
# product_name        object
# report_num          object
# register_date       object
# expiry_date         object
# properties          object
# daily_dose          object
# package_type        object
# storage_caution     object
# warning_info        object
# function_content    object
# standard_info       object
# materials_info      object
# dtype: object

# %%
register_df["register_date"] = pd.to_datetime(register_df["register_date"], format="%Y%m%d", errors="ignore")
register_df = register_df.sort_values(by=["register_date"])
register_df.head()
# Out:
#        Unnamed: 0  register_no  product_search_no    report_num product_name  \
# 28577       28577        28579   2004021000019207  200400150396      해조칼슘비타민
# 28576       28576        28578   2004021000019236  200400150395      영양칼슘비타민
# 28575       28575        28577   2004021000016085  200400200022      일진글루코사민
# 28574       28574        28576   2004021000018903  200400200034         헬스칼슘
# 28572       28572        28574   2004021000021455  200400150704   지근억비피더스베이비
#
#       company_name register_date
# 28577   고려인삼과학주식회사    2004-03-02
# 28576   고려인삼과학주식회사    2004-03-02
# 28575   코스맥스바이오(주)    2004-03-17
# 28574      태웅식품(주)    2004-03-19
# 28572       (주)비피도    2004-03-24

# %% [markdown]
# ### 연도별 건강 기능식품 등록 건수 시각화
# ---

# %%
reigster_reset_date = register_df.set_index('register_date', inplace=True)
quately_count = register_df.resample("YS").count()

# %%
quately_count["register_no"].plot(kind="bar", figsize=(10, 10))

# %% [markdown]
# ### 건기식 카테고리별 등록 건수 분류
#
#
# #### 제목 관련 데이터 전처리 진행.
# ---
#
# - 불용어 제거,다른 태깅 기법 사용
# - Kkma() 사용한 내용

# %%
kkma = Kkma()
pprint(kkma.pos(register_df.product_name[0]))
register_df.product_name[register_df.product_name.str.match("홍삼.*")]
# Out:
# [('해조', 'NNG'), ('칼슘', 'NNG'), ('비타민', 'NNG')]
# register_date
# 2004-05-04         홍삼정(精)골드
# 2004-05-04          홍삼골드타브렛
# 2004-06-03              홍삼분
# 2004-06-09         홍삼정로얄플러스
# 2004-07-08             홍삼분말
#                   ...
# 2020-04-27    홍삼추출물 알지쓰리케이디
# 2020-04-28         홍삼농축액분말7
# 2020-05-08          홍삼농축액12
# 2020-05-08        홍삼농축액분말15
# 2020-05-08         홍삼농축액 원료
# Name: product_name, Length: 928, dtype: object

# %%
# product_name_pos_tags = []

# for i in range(len(register_df)):
#     pos = kkma.nouns(register_df.product_name[i])
# #     pos = [p[0] for p in pos]
#     product_name_pos_tags += pos

# %%
product_name_pos_tags[:10]

# %%
import pickle

# %%
# with open("product_name_post_tag.pickle", "wb") as f:
#     pickle.dump(product_name_pos_tags, f, pickle.HIGHEST_PROTOCOL)
    
with open("product_name_post_tag.pickle", "rb") as f:
    data = pickle.load(f)

# %%
from itertools import chain
from pprint import pprint
all_words = list(chain(*data))
pprint(all_words[:10])
# Out:
# ['해조', '해조칼슘비타민', '칼슘', '비타민', '영양', '영양칼슘비타민', '칼슘', '비타민', '일진', '일진글루코사민']

# %%
from collections import Counter
count = Counter(all_words)

# %%
words = dict(count.most_common())

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords

# %%
# %matplotlib inline 

import matplotlib 
from matplotlib import rc
rc('font', family='Unicode')

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path = '/Library/Fonts/Arial Unicode.ttf',    # 맥에선 한글폰트 설정 잘해야함.
    background_color='white',                             # 배경 색깔 정하기
    colormap = 'Accent_r',                                # 폰트 색깔 정하기
    width = 800,
    height = 800
)

wordcloud_words = wordcloud.generate_from_frequencies(words)

# %%
array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (800, 800, 3)

# %%
from konlpy.tag import Twitter
twitter = Twitter() 
morphs = [] 

for word in words: 
    morphs.append(twitter.pos(word)) 
print(morphs[:10])
# Out:
# /Users/hongnadan/.conda/envs/DataArchitecture/lib/python3.7/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [[('비타민', 'Noun')], [('홍삼', 'Noun')], [('플러스', 'Noun')], [('프로', 'Noun')], [('골드', 'Noun')], [('유산균', 'Noun')], [('바이오', 'Noun')], [('다이어트', 'Noun')], [('수출', 'Noun')], [('프리미엄', 'Noun')]]

# %%
noun_adj_adv_list=[] 
for sentence in morphs : 
    for word, tag in sentence : 
        if tag in ['Noun'] and ("것" not in word) and ("내" not in word)and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word): 
            noun_adj_adv_list.append(word) 

print(noun_adj_adv_list[:10])
# Out:
# ['비타민', '홍삼', '플러스', '프로', '골드', '유산균', '바이오', '다이어트', '프리미엄', '정']

# %%
count = Counter(noun_adj_adv_list)

# %%
words = dict(count.most_common())

# %%
wordcloud_words = wordcloud.generate_from_frequencies(words)
array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (800, 800, 3)

# %% [markdown]
# ### 제품 원료 빈도 수 분석
# ---
#
# - 동일하게 Twitter로 진행

# %%
product_info.head()
# Out:
#   Unnamed: 0 product_info_id   company_name          product_name  \
# 0          0           11413      (주)세종바이오팜         파워액티브비타민C1000
# 1          1           11414  주식회사 코리아헬스바이오   젬무브 생생 이너핏 신프로바이오틱스
# 2          2           11415       주식회사한미양행           비타민D 2000IU
# 3          3           11416         (주)케비젠  다니스코 5종혼합유산균 300B GN
# 4          4           11417       (주)알피바이오         커스텀바이오 엽산400+
#
#         report_num register_date     expiry_date  \
# 0    2019000910535    2020-03-16   제조일로부터 36개월까지
# 1    2020001605212    2020-05-12  제조일로부터 18개월 까지
# 2  200400150831182    2019-08-23            24개월
# 3    2015001001865    2020-01-14            24개월
# 4   20040017006800    2019-11-13     제조일로부터 24개월
#
#                                           properties  \
# 0                      이미·이취가 없으며, 고유의 향미가 있는 미색의 정제
# 1         이미, 이취가 없고 고유의 향미가 있으며 노란색 입자를 포함한 미백색의 분말
# 2  이미, 이취가 없고 고유의 향미가 지닌 흐린 노란연두색의 내용물을 함유한 투명 연질캡슐.
# 3                   이미, 이취가 없고 고유의 향미가 있는 미백색~미황색 분말
# 4             이미, 이취가 없고 고유의 향미가 있는 연한 노란색의 장방형 제피정제
#
#                         daily_dose  \
# 0  1일 1회, 1회 1정을 충분한 물과 함께 섭취하십시오.
# 1  1일 1회, 1회 1포를 충분한 물과 함께 섭취하십시오.
# 2    1일 1회, 1회 1캡슐을 충분한 물과 함께 섭취.
# 3                    건강기능식품 원료로 사용
# 4  1일 1회, 1회 1정을 충분한 물과 함께 섭취하십시오.
#
#                                         package_type  \
# 0       병포장( 용기 - PET, 캡 - PP) / PTP포장(PVC, AL-Foil)
# 1                                          폴리에틸렌(PE)
# 2  폴리에틸렌(PE), 폴리에틸렌테레프탈레이트(PET), 고밀도폴리에틸렌(HDPE), ...
# 3                                          폴리에틸렌(PE)
# 4  PET(폴리에틸렌테레프탈레이트), PE(알루미늄박폴리에틸렌), HDPE(고밀도폴리에...
#
#                                      storage_caution  \
# 0  1) 습기가 적고, 직사광선을 받지 않는 서늘한 곳에 보관하십시오.2) 본 제품은 ...
# 1                              직사광선 및 고온다습한 곳을 피해 보관
# 2                     고온다습한 곳이나 직사광선을 피하여 서늘한 곳에 보관.
# 3                                                 냉장
# 4  고온다습한 곳과 직사광선을 피해 습기가 적고 건조한 곳에 보관하십시오. 어린이의 손...
#
#                                         warning_info  \
# 0                                                NaN
# 1  질환이 있거나 의약품 복용 시 전문가와 상담할 것알레르기 체질 등은 개인에 따라 과...
# 2                  알레르기 체질이신 경우 성분을 확인한 후 섭취하시기 바랍니다
# 3  - 질환이 있거나 의약품 복용 시 전문가와 상담할 것- 알레르기 체질 등은 개인에 ...
# 4  유통기한을 확인하시기 바라며, 섭취량 및 섭취방법을 준수하시기 바랍니다.특이체질이거...
#
#                                     function_content  \
# 0  ①결합조직 형성과 기능유지에 필요②철의 흡수에 필요③유해산소로부터 세포를 보호하는데 필요
# 1  ①정상적인 면역기능에 필요②정상적인 세포분열에 필요① 유익균 증식 및 유해균 억제·...
# 2  [비타민D] 칼슘과 인이 흡수되고 이용되는데 필요, 뼈의 형성과 유지에 필요, 골다...
# 3  ①유산균 증식 및 유해균 억제에 도움을 줄 수 있음 ②배변활동 원활에 도움을 줄 수...
# 4  [엽산] ①세포와 혈액생성에 필요②태아 신경관의 정상 발달에 필요③혈액의 호모시스테...
#
#                                        standard_info  \
# 0  1. 성상: 이미·이취가 없으며, 고유의 향미가 있는 미색의 정제2. 비타민C: 표...
# 1  (1) 성상 : 이미, 이취가 없고 고유의 향미가 있으면 노란색 입자를 포함한 미백...
# 2  (1) 성상 : 이미, 이취가 없고 고유의 향미가 지닌 흐린 노란연두색의 내용물을 ...
# 3  1. 성상: 이미, 이취가 없고 고유의 향미가 있는 미백색~미황색 분말2. 프로바이...
# 4  1) 성상 : 이미, 이취가 없고 고유의 향미가 있는 연한 노란색의 장방형 제피정제...
#
#                                       materials_info
# 0  비타민 C|비타민 C|스테아린산마그네슘|카르복시메틸셀룰로오스|이산화규소|히드록시프로...
# 1  프락토올리고당|프로바이오틱스|아연|산화아연|프로바이오틱스|프로바이오틱스|프락토올리고...
# 2  비타민D|비타민E|D-알파-토코페롤|비타민D3혼합제제|D-소비톨액|에틸바닐린|글리세...
# 3  프로바이오틱스|Bifidobacterium breve|Bifidobacterium ...
# 4  비타민 B12|엽산|레몬추출분말|건조효모|베리혼합분말|목화씨앗|말토덱스트린혼합제제|...

# %%
materials = [str(m).split("|") for m in list(product_info['materials_info'])]

materials[:5]
# Out:
# [['비타민 C', '비타민 C', '스테아린산마그네슘', '카르복시메틸셀룰로오스', '이산화규소', '히드록시프로필메틸셀룰로스', ''],
#  ['프락토올리고당',
#   '프로바이오틱스',
#   '아연',
#   '산화아연',
#   '프로바이오틱스',
#   '프로바이오틱스',
#   '프락토올리고당',
#   '아라비아검',
#   'D-소비톨',
#   '효소처리스테비아',
#   '무수구연산',
#   '덱스트린',
#   '식물성크림',
#   '요구르트향분말',
#   '밀기울식이섬유',
#   '이소말트',
#   'DL-사과산',
#   '치커리식이섬유',
#   '포도당',
#   '요구르트 혼합',
#   ''],
#  ['비타민D',
#   '비타민E',
#   'D-알파-토코페롤',
#   '비타민D3혼합제제',
#   'D-소비톨액',
#   '에틸바닐린',
#   '글리세린',
#   '젤라틴',
#   '포도씨앗유',
#   ''],
#  ['프로바이오틱스',
#   'Bifidobacterium breve',
#   'Bifidobacterium bifidum',
#   'Lactobacillus plantarum',
#   'Lactobacillus acidophilus',
#   'Bifidobacterium animalis ssp. lactis',
#   '덱스트린',
#   ''],
#  ['비타민 B12',
#   '엽산',
#   '레몬추출분말',
#   '건조효모',
#   '베리혼합분말',
#   '목화씨앗',
#   '말토덱스트린혼합제제',
#   '덱스트린',
#   '과일채소혼합분말',
#   '과일채소혼합분말',
#   '옥수수전분',
#   '밀식이섬유',
#   '']]

# %%
from itertools import chain
from pprint import pprint
all_materials = [w for w in list(chain(*materials)) if w is not ""]
all_materials = [w for w in all_materials if w is not "None"]
pprint(all_materials[:10])
# Out:
# ['비타민 C',
#  '비타민 C',
#  '스테아린산마그네슘',
#  '카르복시메틸셀룰로오스',
#  '이산화규소',
#  '히드록시프로필메틸셀룰로스',
#  '프락토올리고당',
#  '프로바이오틱스',
#  '아연',
#  '산화아연']

# %%
count = Counter(all_materials)

# %%
material_dic = dict(count.most_common())

del material_dic["None"]

# %%
wordcloud_words = wordcloud.generate_from_frequencies(material_dic)
array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (800, 800, 3)

# %%
material_count_list = [[name, material_dic[name]] for name in material_dic.keys()]

material_count_list[:10]
# Out:
# [['스테아린산마그네슘', 6466],
#  ['비타민 C', 5488],
#  ['이산화규소', 4971],
#  ['비타민 B2', 4967],
#  ['아연', 4565],
#  ['건조효모', 4430],
#  ['산화아연', 4211],
#  ['정제수', 4016],
#  ['젤라틴', 3932],
#  ['프락토올리고당', 3911]]

# %%
material_df = pd.DataFrame(material_count_list, columns = ['name', "count"])


print(f"material_df = {material_df.shape}")
material_df.head()
# Out:
# material_df = (7010, 2)
#         name  count
# 0  스테아린산마그네슘   6466
# 1      비타민 C   5488
# 2      이산화규소   4971
# 3     비타민 B2   4967
# 4         아연   4565

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.distplot(list(material_df['count']))
plt.title("Material Count Dist")
plt.show()

# %%
sns.boxplot(material_df['count'])

# %% [markdown]
# ### 주의사항 데이터 분석

# %% [markdown]
# ##### 주의사항이 빠진 제품들이 있는데, 과연 해당 제품의 각 원료들에도 부작용이 없는지 검증 필요.
# ##### 추가로 다른 제품들에도 주의사항 키워드에 해당 제품의 원료들에 대한 부작용이 다 포함되어 있는지 확인.

# %%
warning_na_count = len([isna for isna in product_info.warning_info.isna() if isna == True])
print(f"전체 제품의 수 : {len(product_info)}, 주의사항이 빠진 제품의 수 = {warning_na_count}")
print(f"주의사항이 빠진 제품의 비율 = {warning_na_count / len(product_info) * 100}%")
# Out:
# 전체 제품의 수 : 69875, 주의사항이 빠진 제품의 수 = 45025
# 주의사항이 빠진 제품의 비율 = 64.43649373881932%

# %%
"유단백가수분해물" in all_materials
# Out:
# True

# %%
all_materials[:10]
# Out:
# ['비타민 C',
#  '비타민 C',
#  '스테아린산마그네슘',
#  '카르복시메틸셀룰로오스',
#  '이산화규소',
#  '히드록시프로필메틸셀룰로스',
#  '프락토올리고당',
#  '프로바이오틱스',
#  '아연',
#  '산화아연']
